# %%
from pathlib import Path

# Data preparation
from grna_inspector.data_preparation import gRNADataPreparator

# %%
from grna_inspector.data_preparation import gRNADataPreparator

# Initialize preparator
data_dir = Path('data')
preparator = gRNADataPreparator(data_dir)

# Prepare dataset (this will take a few minutes)
train_df, val_df, test_df = preparator.prepare_dataset(
    test_size=0.15,
    val_size=0.15,
    balance_ratio=1.0,  # 1:1 positive to negative ratio
    random_state=42
)

# Datasets are automatically saved to data/processed/
